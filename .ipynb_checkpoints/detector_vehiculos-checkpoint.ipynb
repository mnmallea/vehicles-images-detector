# %% [markdown]
# # RNA Multi-Perceptrón Backpropagation para procesar las imágenes e identificar si es auto, moto ó camión.

# %% [markdown]
# 1) Cargar librerías:

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import keras
from keras.layers import Input, Dense, Flatten
from keras.models import Model
from keras.utils import plot_model

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import os

from PIL import Image

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

import sys
IS_COLAB = 'google.colab' in sys.modules

if IS_COLAB:
  print('Running on Google Colab')

print("Librerías cargadas")
# Out:
# Using TensorFlow backend.
# Librerías cargadas

# %% [markdown]
# 2) Definir los parámetros:

# %%
# tamaño de las imágenes
IMAGE_HEIGHT = 32
IMAGE_WIDTH = 32
IMAGE_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, 1)

# define tamaño de datos de entrada 
num_inputs = IMAGE_SHAPE[0] * IMAGE_SHAPE[1] * IMAGE_SHAPE[2]


# define tamaño de datos de salida (las clases están codificadas en un único número)
num_outputs = 1 

# cantidad de neuronas ocultas 
hidden_layers_neuron_counts = [ 784, 392, 56, 32 ] 

# cantidad de épocas del entrenamiento
cantEpocas = 100

print("Configuración de RNA MLP Backpropagation definida: [", num_inputs, hidden_layers_neuron_counts, num_outputs," ] ")
# Out:
# Configuración de RNA MLP Backpropagation definida: [ 1024 [784, 392, 56, 32] 1  ]

# %% [markdown]
# 3) Descarga las imagenes de drive, si se está corriendo en colab:

# %%
# Recursively copies a remote directory from gdrive to a local one
def copy_gdrive_directory(source_id, local_target):
  try:
    os.makedirs(local_target)
  except: 
    pass
  file_list = drive.ListFile({'q': "'{source_id}' in parents".format(source_id=source_id)}).GetList()
  for f in file_list:
    print(f)
    if f["title"].startswith("."):
      continue
    fname = os.path.join(local_target, f['title'])
    if f['mimeType'] == 'application/vnd.google-apps.folder':
      copy_directory(f['id'], fname)
    else:
      f_ = drive.CreateFile({'id': f['id']})
      f_.GetContentFile(fname)

# %%
if IS_COLAB:
    DATASET_PATH = '/content/datasets'
else:
    DATASET_PATH = './datasets'

if IS_COLAB:
    from pydrive.auth import GoogleAuth
    from pydrive.drive import GoogleDrive
    from google.colab import auth
    from oauth2client.client import GoogleCredentials
    auth.authenticate_user()
    gauth = GoogleAuth()
    gauth.credentials = GoogleCredentials.get_application_default()
    drive = GoogleDrive(gauth)

    folder_id = '1O4O3HaXwHL-HFi4bWZIX2PcOztXfJpt0'

    file_list = drive.ListFile({'q': "'{}' in parents and trashed=false".format(folder_id)}).GetList()

    copy_drive_directory(folder_id, DATASET_PATH)

IMAGE_CLASSES = ['car', 'motorcycle', 'truck']
RAW_PATH = os.path.join(DATASET_PATH, 'raw')
MINIFIED_PATH = os.path.join(DATASET_PATH, 'minified')

print('Done!')
# Out:
# Done!

# %% [markdown]
# ## Preprocesamiento de imágenes
# Las imágenes se achican a un tamaño de 32x32 y se convierten a escala de grises.

# %%
def minimized_image(image):
    return image.convert('L').resize((IMAGE_HEIGHT, IMAGE_WIDTH), Image.ANTIALIAS)

def minify_image_from_class(from_directory, to_directory):
    for root, dirs, files in os.walk(from_directory):
        for image_name in files:
            image_path = os.path.join(root, image_name)
            image = Image.open(image_path)
            image = minimized_image(image)
            image.save(os.path.join(to_directory, image_name))

for image_class in IMAGE_CLASSES:
    input_dir = os.path.join(RAW_PATH, image_class)
    output_dir = os.path.join(MINIFIED_PATH, image_class)
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    minify_image_from_class(input_dir, output_dir)

print('Done')
# Out:
# Done

# %%
import math
import re
import sys
import shutil

DISTRIBUTED_PATH = os.path.join(DATASET_PATH, 'distributed')
#Train and Test Set Variables
train_val_test_ratio = (.7,.1,.2) # 70/10/20 Data Split
test_folder = os.path.join(DISTRIBUTED_PATH, 'test')
train_folder = os.path.join(DISTRIBUTED_PATH, 'train')
val_folder = os.path.join(DISTRIBUTED_PATH, 'val')

#Remove Existing Folders if they exist
for folder in [test_folder, train_folder, val_folder]:
    if os.path.exists(folder) and os.path.isdir(folder):
        shutil.rmtree(folder)

#Remake Category Folders in both Train and Test Folders
for category in IMAGE_CLASSES:
    os.makedirs(os.path.join(test_folder, category))
    os.makedirs(os.path.join(train_folder, category))
    os.makedirs(os.path.join(val_folder, category))

#Split Data by Train Ratio and copy files to correct directory
for idx, category in enumerate(IMAGE_CLASSES):
    file_list = os.listdir(os.path.join(MINIFIED_PATH, category))
    
    train_ratio = math.floor(len(file_list) * train_val_test_ratio[0])
    val_ratio = math.floor(len(file_list) * train_val_test_ratio[1])
    train_list = file_list[:train_ratio]
    val_list = file_list[train_ratio:train_ratio + val_ratio]
    test_list = file_list[train_ratio + val_ratio:]
    
    for i, file in enumerate(train_list):
        shutil.copy(os.path.join(MINIFIED_PATH, category, file), os.path.join(train_folder, category, file))
    sys.stdout.write('Moving %s train images to category folder %s' % (len(train_list), category))  
    sys.stdout.write('\n')
    for i, file in enumerate(val_list):
        shutil.copy(os.path.join(MINIFIED_PATH, category, file), os.path.join(val_folder, category, file))
    sys.stdout.write('Moving %s validation images to category folder %s' % (len(val_list), category))                   
    sys.stdout.write('\n')
    for i, file in enumerate(test_list):
        shutil.copy(os.path.join(MINIFIED_PATH, category, file), os.path.join(test_folder, category, file))
    sys.stdout.write('Moving %s test images to category folder %s' % (len(test_list), category))
    sys.stdout.write('\n\n')
    
print("Done.")
# Out:
# Moving 322 train images to category folder car
# Moving 46 validation images to category folder car
# Moving 93 test images to category folder car
#
# Moving 200 train images to category folder motorcycle
# Moving 28 validation images to category folder motorcycle
# Moving 58 test images to category folder motorcycle
#
# Moving 436 train images to category folder truck
# Moving 62 validation images to category folder truck
# Moving 125 test images to category folder truck
#
# Done.

# %% [markdown]
# 4) Cargar imágenes para entrenar el modelo:

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.inception_v3 import preprocess_input, decode_predictions

BATCH_SIZE=64

train_datagen = ImageDataGenerator(  
    rescale=1. / 255,
    zoom_range=0.2,
    rotation_range = 5,
    horizontal_flip=True)

#Train DataSet Generator with Augmentation
print("\nTraining Data Set")
train_flow = train_datagen.flow_from_directory(
    train_folder,
    target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size = BATCH_SIZE
)

print(train_flow)

#Validation DataSet Generator with Augmentation
print("\nValidation Data Set")
val_flow = train_datagen.flow_from_directory(
    val_folder,
    target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size = BATCH_SIZE
)

#Test DataSet Generator with Augmentation
print("\nTest Data Set")
test_flow = train_datagen.flow_from_directory(
    test_folder,
    target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size = BATCH_SIZE
)
# Out:
# Training Data Set
# Found 958 images belonging to 3 classes.
# <keras.preprocessing.image.DirectoryIterator object at 0x7fe811a78ad0>
#
# Validation Data Set
# Found 136 images belonging to 3 classes.
#
# Test Data Set
# Found 276 images belonging to 3 classes.

# %%
def show_batch(image_batch, label_batch):
  plt.figure(figsize=(10,10))
  for n in range(25):
      ax = plt.subplot(5,5,n+1)
      plt.imshow(image_batch[n])
      plt.axis('off')

image_batch = next(train_flow)
show_batch(image_batch, label_batch)

image_batch = next(val_flow)
show_batch(image_batch, label_batch)

# %%
import functools

input_layer = Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
base_model = Flatten()(input_layer)

hidden_layers = functools.reduce(lambda previous_layer, neurons_count: Dense(neurons_count, activation="relu")(previous_layer), hidden_layers_neuron_counts, base_model)

output_layer = Dense(3, activation='softmax', name='output')(hidden_layers)

model = Model(input_layer, output_layer)
model.compile(optimizer='rmsprop', loss='mse', metrics=['accuracy'])

model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 784)               2409232
# _________________________________________________________________
# dense_6 (Dense)              (None, 392)               307720
# _________________________________________________________________
# dense_7 (Dense)              (None, 56)                22008
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                1824
# _________________________________________________________________
# output (Dense)               (None, 3)                 99
# =================================================================
# Total params: 2,740,883
# Trainable params: 2,740,883
# Non-trainable params: 0
# _________________________________________________________________

# %%
import math

model.fit(train_flow, epochs = cantEpocas, validation_data=val_flow)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 2s 143ms/step - loss: 0.4377 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 2/100
# 15/15 [==============================] - 2s 140ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 3/100
# 15/15 [==============================] - 2s 138ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 4/100
# 15/15 [==============================] - 2s 147ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 5/100
# 15/15 [==============================] - 2s 146ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 6/100
# 15/15 [==============================] - 2s 142ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.1667 - val_accuracy: 0.3382
# Epoch 7/100
# 15/15 [==============================] - 2s 154ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.2500 - val_accuracy: 0.3382
# Epoch 8/100
# 15/15 [==============================] - 2s 148ms/step - loss: 0.4424 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 9/100
# 15/15 [==============================] - 2s 154ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 10/100
# 15/15 [==============================] - 2s 156ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 11/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 12/100
# 15/15 [==============================] - 2s 147ms/step - loss: 0.4424 - accuracy: 0.3361 - val_loss: 0.5833 - val_accuracy: 0.3382
# Epoch 13/100
# 15/15 [==============================] - 3s 171ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 14/100
# 15/15 [==============================] - 2s 162ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.2500 - val_accuracy: 0.3382
# Epoch 15/100
# 15/15 [==============================] - 2s 160ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 16/100
# 15/15 [==============================] - 2s 148ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.6667 - val_accuracy: 0.3382
# Epoch 17/100
# 15/15 [==============================] - 2s 159ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 18/100
# 15/15 [==============================] - 2s 157ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 19/100
# 15/15 [==============================] - 3s 171ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.2500 - val_accuracy: 0.3382
# Epoch 20/100
# 15/15 [==============================] - 2s 153ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 21/100
# 15/15 [==============================] - 3s 167ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 22/100
# 15/15 [==============================] - 3s 177ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 23/100
# 15/15 [==============================] - 2s 152ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5833 - val_accuracy: 0.3382
# Epoch 24/100
# 15/15 [==============================] - 3s 184ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 25/100
# 15/15 [==============================] - 2s 149ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.5833 - val_accuracy: 0.3382
# Epoch 26/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 27/100
# 15/15 [==============================] - 2s 155ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 28/100
# 15/15 [==============================] - 3s 167ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 29/100
# 15/15 [==============================] - 2s 157ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 30/100
# 15/15 [==============================] - 3s 169ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.5833 - val_accuracy: 0.3382
# Epoch 31/100
# 15/15 [==============================] - 2s 142ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.2500 - val_accuracy: 0.3382
# Epoch 32/100
# 15/15 [==============================] - 2s 145ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 33/100
# 15/15 [==============================] - 3s 167ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 34/100
# 15/15 [==============================] - 2s 153ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 35/100
# 15/15 [==============================] - 2s 153ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 36/100
# 15/15 [==============================] - 2s 130ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 37/100
# 15/15 [==============================] - 2s 159ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 38/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 39/100
# 15/15 [==============================] - 2s 147ms/step - loss: 0.4424 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 40/100
# 15/15 [==============================] - 2s 157ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5833 - val_accuracy: 0.3382
# Epoch 41/100
# 15/15 [==============================] - 3s 168ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 42/100
# 15/15 [==============================] - 2s 136ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 43/100
# 15/15 [==============================] - 2s 147ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 44/100
# 15/15 [==============================] - 2s 160ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 45/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5833 - val_accuracy: 0.3382
# Epoch 46/100
# 15/15 [==============================] - 2s 153ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 47/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 48/100
# 15/15 [==============================] - 2s 147ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 49/100
# 15/15 [==============================] - 2s 162ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 50/100
# 15/15 [==============================] - 3s 177ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 51/100
# 15/15 [==============================] - 3s 178ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 52/100
# 15/15 [==============================] - 2s 162ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.1667 - val_accuracy: 0.3382
# Epoch 53/100
# 15/15 [==============================] - 2s 159ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.2500 - val_accuracy: 0.3382
# Epoch 54/100
# 15/15 [==============================] - 3s 169ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 55/100
# 15/15 [==============================] - 2s 152ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 56/100
# 15/15 [==============================] - 2s 128ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.2500 - val_accuracy: 0.3382
# Epoch 57/100
# 15/15 [==============================] - 2s 161ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5833 - val_accuracy: 0.3382
# Epoch 58/100
# 15/15 [==============================] - 3s 175ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.1667 - val_accuracy: 0.3382
# Epoch 59/100
# 15/15 [==============================] - 2s 161ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 60/100
# 15/15 [==============================] - 2s 162ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.6667 - val_accuracy: 0.3382
# Epoch 61/100
# 15/15 [==============================] - 2s 166ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 62/100
# 15/15 [==============================] - 2s 152ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 63/100
# 15/15 [==============================] - 2s 146ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 64/100
# 15/15 [==============================] - 3s 178ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 65/100
# 15/15 [==============================] - 2s 152ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5833 - val_accuracy: 0.3382
# Epoch 66/100
# 15/15 [==============================] - 2s 149ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 67/100
# 15/15 [==============================] - 3s 168ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 68/100
# 15/15 [==============================] - 2s 135ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 69/100
# 15/15 [==============================] - 2s 153ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 70/100
# 15/15 [==============================] - 2s 153ms/step - loss: 0.4428 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 71/100
# 15/15 [==============================] - 3s 179ms/step - loss: 0.4424 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 72/100
# 15/15 [==============================] - 3s 196ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 73/100
# 15/15 [==============================] - 2s 159ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 74/100
# 15/15 [==============================] - 2s 162ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 75/100
# 15/15 [==============================] - 2s 148ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 76/100
# 15/15 [==============================] - 3s 168ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 77/100
# 15/15 [==============================] - 2s 157ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5833 - val_accuracy: 0.3382
# Epoch 78/100
# 15/15 [==============================] - 3s 197ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.5833 - val_accuracy: 0.3382
# Epoch 79/100
# 15/15 [==============================] - 3s 173ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.2500 - val_accuracy: 0.3382
# Epoch 80/100
# 15/15 [==============================] - 2s 158ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 81/100
# 15/15 [==============================] - 2s 150ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 82/100
# 15/15 [==============================] - 2s 148ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.2500 - val_accuracy: 0.3382
# Epoch 83/100
# 15/15 [==============================] - 3s 169ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.2500 - val_accuracy: 0.3382
# Epoch 84/100
# 15/15 [==============================] - 3s 182ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 85/100
# 15/15 [==============================] - 3s 176ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 86/100
# 15/15 [==============================] - 2s 154ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.5833 - val_accuracy: 0.3382
# Epoch 87/100
# 15/15 [==============================] - 2s 161ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.2500 - val_accuracy: 0.3382
# Epoch 88/100
# 15/15 [==============================] - 3s 177ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5833 - val_accuracy: 0.3382
# Epoch 89/100
# 15/15 [==============================] - 2s 159ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.2500 - val_accuracy: 0.3382
# Epoch 90/100
# 15/15 [==============================] - 3s 173ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.2500 - val_accuracy: 0.3382
# Epoch 91/100
# 15/15 [==============================] - 3s 173ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 92/100
# 15/15 [==============================] - 2s 151ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 93/100
# 15/15 [==============================] - 2s 154ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 94/100
# 15/15 [==============================] - 2s 152ms/step - loss: 0.4425 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 95/100
# 15/15 [==============================] - 2s 160ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382
# Epoch 96/100
# 15/15 [==============================] - 3s 169ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.2500 - val_accuracy: 0.3382
# Epoch 97/100
# 14/15 [===========================>..] - ETA: 0s - loss: 0.4415 - accuracy: 0.3315/15 [==============================] - 2s 153ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.5833 - val_accuracy: 0.3382
# Epoch 98/100
# 15/15 [==============================] - 3s 179ms/step - loss: 0.4426 - accuracy: 0.3361 - val_loss: 0.4167 - val_accuracy: 0.3382
# Epoch 99/100
# 15/15 [==============================] - 3s 181ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.5000 - val_accuracy: 0.3382
# Epoch 100/100
# 15/15 [==============================] - 2s 162ms/step - loss: 0.4427 - accuracy: 0.3361 - val_loss: 0.3333 - val_accuracy: 0.3382

# %%
loss, acc = model.evaluate_generator(test_flow, verbose = True, steps=math.ceil(test_flow.samples/test_flow.batch_size))
print("Loss: ", loss)
print("Acc: ", acc)
# Out:
# 5/5 [==============================] - 0s 80ms/step
# Loss:  0.366666704416275
# Acc:  0.33695653080940247

# %%
# Loads images and labels into numpy arrays
def load_img_directory(dir_path):
  classes = []
  images = []
  for class_name in os.listdir(dir_path):
    print(class_name)
    for image_name in os.listdir(os.path.join(dir_path, class_name)):          
          image = Image.open(os.path.join(dir_path, class_name, image_name))
          images.append(np.array(image))
          classes.append(class_name)
  return (images, classes)

# %%
# cargar las imágenes

(x_train, y_train) = load_img_directory(train_folder)
(x_val, y_val) = load_img_directory(val_folder)
(x_test, y_test) = load_img_directory(test_folder)

print('Dataset de train')
print("- Clases cargadas: ", len(set(y_train)))
print("- Imágenes cargadas: ", len(x_train))

print('Dataset de validación')
print("- Clases cargadas validación: ", len(set(y_val)))
print("- Imágenes cargadas validación: ", len(x_val))

print('Dataset de test')
print("- Clases cargadas test: ", len(set(y_test)))
print("- Imágenes cargadas test: ", len(x_test))

if len(x_train) > 0:
  print("\n- Ejemplo ", y_train[0], " ", x_train[0].shape, ": ")
  display( Image.fromarray(x_train[0], 'L') )
# Out:
# motorcycle
# car
# truck
# motorcycle
# car
# truck
# motorcycle
# car
# truck
# Dataset de train
# - Clases cargadas:  3
# - Imágenes cargadas:  958
# Dataset de validación
# - Clases cargadas validación:  3
# - Imágenes cargadas validación:  136
# Dataset de test
# - Clases cargadas test:  3
# - Imágenes cargadas test:  276
#
# - Ejemplo  motorcycle   (32, 32) :
# <PIL.Image.Image image mode=L size=32x32 at 0x7FE829024290>

# %%
# define función auxiliar para mostrar imágenes preparadas
def plot_image(imag):
  if IMAGE_SHAPE[2]==1:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE[0], IMAGE_SHAPE[1]).astype(np.uint8))
    plt.gray()
  else:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE).astype(np.uint8))
  plt.axis("off")  

# define función auxiliar para preparar la lista de imágenes a procesar
def process_images_array(images):    
  images = np.array(images).astype('float32') / 255.
  return images.reshape((len(images), num_inputs))

def process_classes_array(classes):
  mapped = []
  for klass in classes:
    mapped.append(IMAGE_CLASSES_MAP[klass])
  return mapped

# define vector auxiliar de datos de entrada para usar en el entrenamiento
_x_train = process_images_array(x_train)
_x_test = process_images_array(x_test)
_x_val = process_images_array(x_val)

# define vector auxiliar de datos de salida para usar en el entrenamiento
# también usa esta información para determinar la cantida de neuronas de salida
print(IMAGE_CLASSES)
IMAGE_CLASSES_MAP = dict(zip(IMAGE_CLASSES, range(len(IMAGE_CLASSES))))
print(IMAGE_CLASSES_MAP)

_y_train = process_classes_array(y_train)
_y_test = process_classes_array(y_test)
_y_val = process_classes_array(y_val)

print("x_train (cant ejemplos, datos entrada): ", _x_train.shape)
print("y_train (cant): ", len(y_train))
print("\nImagen reconstruida de ", _y_train[0])

plot_image(x_train[0])
# Out:
# ['car', 'motorcycle', 'truck']
# {'car': 0, 'motorcycle': 1, 'truck': 2}
# x_train (cant ejemplos, datos entrada):  (958, 1024)
# y_train (cant):  958
#
# Imagen reconstruida de  1

# %% [markdown]
# 5) Establecer el modelo para la RNA:

# %% [markdown]
# 6) Entrenar el modelo de la RNA:

# %%
import keras
import pydot as pyd
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

keras.utils.vis_utils.pydot = pyd

#Visualize Model Helper function
def visualize_model(model):
  return SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
import functools
import pydot

input_layer = Input(shape=(IMAGE_HEIGHT * IMAGE_WIDTH,))

hidden_layers = functools.reduce(   lambda previous_layer, neurons_count: Dense(neurons_count, activation="relu")(previous_layer),
                                    hidden_layers_neuron_counts,
                                    input_layer)

output_layer = Dense(num_outputs, activation=None, name='output')(hidden_layers)

model = Model(input_layer, output_layer)
model.compile(optimizer='rmsprop', loss='mse', metrics=['accuracy'])

model.summary()
visualize_model(model)
# Out:
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        (None, 1024)              0
# _________________________________________________________________
# dense_41 (Dense)             (None, 784)               803600
# _________________________________________________________________
# dense_42 (Dense)             (None, 392)               307720
# _________________________________________________________________
# dense_43 (Dense)             (None, 56)                22008
# _________________________________________________________________
# dense_44 (Dense)             (None, 32)                1824
# _________________________________________________________________
# output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 1,135,185
# Trainable params: 1,135,185
# Non-trainable params: 0
# _________________________________________________________________

# %%
# lleva a cabo el entrenamiento
model.fit(_x_train, _y_train,
                epochs = cantEpocas, 
                batch_size = 5,
                validation_data=(_x_val, _y_val))
# Out:
# Train on 958 samples, validate on 136 samples
# Epoch 1/100
# 958/958 [==============================] - 5s 6ms/step - loss: 1.2108 - accuracy: 0.3413 - val_loss: 0.8048 - val_accuracy: 0.5294
# Epoch 2/100
# 958/958 [==============================] - 5s 5ms/step - loss: 0.6927 - accuracy: 0.3612 - val_loss: 0.8000 - val_accuracy: 0.5662
# Epoch 3/100
# 958/958 [==============================] - 5s 5ms/step - loss: 0.6517 - accuracy: 0.4102 - val_loss: 0.5817 - val_accuracy: 0.4926
# Epoch 4/100
# 958/958 [==============================] - 5s 5ms/step - loss: 0.6010 - accuracy: 0.4040 - val_loss: 0.5828 - val_accuracy: 0.4191
# Epoch 5/100
# 958/958 [==============================] - 5s 5ms/step - loss: 0.5749 - accuracy: 0.4635 - val_loss: 0.7195 - val_accuracy: 0.3015
# Epoch 6/100
# 958/958 [==============================] - 4s 4ms/step - loss: 0.5477 - accuracy: 0.4666 - val_loss: 0.7229 - val_accuracy: 0.5662
# Epoch 7/100
# 958/958 [==============================] - 5s 5ms/step - loss: 0.5424 - accuracy: 0.4927 - val_loss: 0.6443 - val_accuracy: 0.5662
# Epoch 8/100
# 958/958 [==============================] - 5s 5ms/step - loss: 0.5275 - accuracy: 0.5125 - val_loss: 0.6816 - val_accuracy: 0.5735
# Epoch 9/100
# 958/958 [==============================] - 5s 6ms/step - loss: 0.4949 - accuracy: 0.5313 - val_loss: 0.5626 - val_accuracy: 0.5588
# Epoch 10/100
# 958/958 [==============================] - 5s 5ms/step - loss: 0.
# %% [markdown]
# 7) Evaluar el modelo de la RNA entrenado:
#    (notar que utiliza las mismas imágenes de test!)

# %%
 # evalua al modelo entrenado
loss, accuracy = model.evaluate(_x_test, _y_test)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", loss * 100, "%")
print("    - Exactitud: ", accuracy * 100,"%")
print("\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-090565e7d36d> in <module>
#       1 # evalua al modelo entrenado
# ----> 2 loss, accuracy = model.evaluate(_x_test, _y_test)
#       3 print("\n>Evaluación del Modelo: ")
#       4 print("    - Error: ", loss * 100, "%")
#       5 print("    - Exactitud: ", accuracy * 100,"%")
#
# NameError: name 'model' is not defined

# %%
import glob
import random

file_list = glob.glob(test_folder + '/**/**.jpg')
img_path = random.choice(file_list)
img_cat = os.path.split(os.path.dirname(img_path))[1]
print("Image Category: ", img_cat)
img = Image.open(img_path)
X = np.array(img)

reversed_dictionary = dict(map(reversed, IMAGE_CLASSES_MAP.items()))

print("Category: ", reversed_dictionary)

result = model.predict(process_images_array([X]))[0][0]
print("Raw prediction: ", result)
print("Prediction: ", reversed_dictionary[round(result)])

plt.imshow(img)
plot_image(X)
# Out:
# Image Category:  car
# Category:  {0: 'car', 1: 'motorcycle', 2: 'truck'}
# Raw prediction:  1.8962601
# Prediction:  truck

# %%
# procesa las imágenes con el modelo 
predClass = model.predict(x_test)

# muestra los resultados con las imágenes 
umbralClas = 0.5
classPreds = []
classReal = []
for i in range(len(x_test)):

    # prepara salida
    clReal = classes_ori_test[i]
    idclPred = predClass[i][0]

    ## determina clase predecida de acuerdo al umbral de clasificación
    idclPredRnd = int(idclPred)
    if (idclPred - idclPredRnd) > 0.5 and (idclPredRnd+1) < len(SPECIES):
            idclPredRnd = idclPredRnd + 1

    if idclPredRnd < 0 or idclPredRnd >= len(SPECIES):
        clPred = "INVÁLIDA!"
    else:      
        clPred = SPECIES[ idclPredRnd ]

    classReal.append( clReal )
    classPreds.append( clPred )

    strTitulo = 'Real: ' + clReal + ' / RNA: ' 
    strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'    

    # muestra comparación con la imagen
    fig = plt.figure()
    fig.suptitle( strTitulo )
    ax1 = fig.add_subplot(121)
    plot_image(x_test[i])
    
    plt.tight_layout()
    fig = plt.gcf()

# muestra reporte de clasificación
print("\n Reporte de Clasificación: ")
print(classification_report(classReal, classPreds))

# muestra matriz de confusion
print('\nMatriz de Confusión: ')
cm = confusion_matrix(classReal, classPreds, labels=SPECIES)
cmtx = pd.DataFrame(
    cm, 
    index=['r:{:}'.format(x) for x in SPECIES], 
    columns=['p:{:}'.format(x) for x in SPECIES]
  )
print(cmtx)
print("\n")

print("\n>Resultados: ")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#    INVÁLIDA!       0.00      0.00      0.00         0
#          car       0.82      0.70      0.75       195
#   motorcycle       0.42      0.73      0.53        95
#        truck       0.94      0.26      0.41        61
#
#     accuracy                           0.63       351
#    macro avg       0.54      0.42      0.42       351
# weighted avg       0.73      0.63      0.63       351
#
#
# Matriz de Confusión:
#               p:car  p:motorcycle  p:truck
# r:car           136            56        1
# r:motorcycle     26            69        0
# r:truck           4            41       16
#
#
#
# >Resultados:
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
